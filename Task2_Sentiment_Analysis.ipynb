# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df1=pd.read_csv('Movie_description.csv')
print('Movie Sentiment Analysis')
def sentiment_detection(description):
  positive = False
  negative = False
  for i in ('Stunning', 'Thrilling','Astounding', 'Beautiful', 'Amazing', 'Brilliant', 'Awe-Inspiring', 'Action-Packed'):
    if i in description:
      positive = True
  for i in ('Sad', 'Scary','Mad', 'Boring', 'Emotional'):
    if i in description:
      negative = True
  if positive == negative == False:
    return "neutral"
  elif positive == True != negative:
    return "positive"
  elif negative == True != positive:
    return 'negative'
  else:
    return "mixed"
df1['Sentiment_Classification'] = df1['description'].apply(lambda x: sentiment_detection(x))
df1
# Out:
# Movie Sentiment Analysis
#      film_id              title  \
# 0          1   Academy Dinosaur
# 1          2     Ace Goldfinger
# 2          3   Adaptation Holes
# 3          4   Affair Prejudice
# 4          5        African Egg
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...
# 1    A Astounding Epistle of a Database Administrat...
# 2    A Astounding Reflection of a Lumberjack And a ...
# 3    A Fanciful Documentary of a Frisbee And a Lumb...
# 4    A Fast-Paced Documentary of a Pastry Chef And ...
# ..                                                 ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...
# 996  A Touching Drama of a Teacher And a Cat who mu...
# ...
